# %%
# %magic

import torch
import numpy as np
import matplotlib.pyplot as plt
import librosa
import soundfile as sf
from pydub import AudioSegment
import IPython

# %%
# %ls /import/c4dm-datasets/VocalSet1-2/data_by_singer/
# Out:
# female1/  female4/  female7/  male1/   male2/  male5/  male8/
# female2/  female5/  female8/  male10/  male3/  male6/  male9/
# female3/  female6/  female9/  male11/  male4/  male7/

# %%
src_path = '/import/c4dm-datasets/VocalSet1-2/data_by_singer/male7/scales/lip_trill/m7_scales_lip_trill_a.wav'

def detect_leading_silence(audio_seg, silence_thresh=-60.0, chunk_size=10):
    # From https://stackoverflow.com/questions/29547218/
    silence_found = False
    while silence_found == False:
        silence_thresh -=2 
        for time_step in range(0,len(audio_seg),chunk_size):
            if audio_seg[time_step:time_step+chunk_size].dBFS > silence_thresh:
                silence_found = True
                break
    return time_step

audio_seg = AudioSegment.from_file(src_path, format='wav')
full_duration = len(audio_seg)
start_trim = detect_leading_silence(audio_seg)
end_trim = detect_leading_silence(audio_seg.reverse())
trimmed_audio = audio_seg[start_trim:full_duration-end_trim]
trimmed_duration = len(trimmed_audio)
print(full_duration, trimmed_duration)
trimmed_audio.export('./silence_trimmed_audio.wav', format="wav")
IPython.display.Audio('./silence_trimmed_audio.wav')
# Out:
# 3659 3489
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
qwe = torch.empty(3,2)
asd = torch.empty(3,2)
zxc = torch.empty(3,2)
uio = torch.empty(3,2)

latest = qwe.unsqueeze(0)
print(latest.shape)
tmp = asd.unsqueeze(0)
print(tmp.shape)
latest = torch.cat((latest,tmp))
print(latest.shape)
tmp = zxc.unsqueeze(0)
print(tmp.shape)
latest = torch.cat((latest,tmp))
print(latest.shape)
latest

# rty = torch.cat((qwe,asd))
# print(rty.shape)
# zxc = zxc.unsqueeze(0)
# print(asd.shape)

# fgh = torch.cat((rty,zxc))
# print(fgh.shape)
# fgh

# uio = uio.unsqueeze(0)
# vbn = torch.cat((fgh,uio))
# vbn.shape
# Out:
# torch.Size([1, 3, 2])
# torch.Size([1, 3, 2])
# torch.Size([2, 3, 2])
# torch.Size([1, 3, 2])
# torch.Size([3, 3, 2])
# tensor([[[4.3971e-04, 4.5733e-41],
#          [2.4401e-37, 0.0000e+00],
#          [0.0000e+00, 0.0000e+00]],
#
#         [[0.0000e+00, 0.0000e+00],
#          [0.0000e+00, 0.0000e+00],
#          [0.0000e+00, 0.0000e+00]],
#
#         [[2.0718e-35, 0.0000e+00],
#          [2.8741e-37, 0.0000e+00],
#          [1.1210e-43, 0.0000e+00]]])

# %%
qwe = torch.empty(3,2)
asd = torch.empty(3,2)
zxc = torch.empty(3,2)

first = qwe

second = torch.cat((qwe,asd), dim=0)
second.shape

# rty = torch.stack((qwe,asd))
# print(rty.shape)
# zxc = zxc.unsqueeze(0)
# print(asd.shape)

# fgh = torch.cat((rty,zxc))
# print(fgh.shape)
# fgh
# Out:
# torch.Size([6, 2])

# %%
for spmel in qwe:
    spmel = np.rot90(spmel)
    plt.imshow(qwe0, cmap='gray')
    plt.show()
