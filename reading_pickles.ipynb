# %%
import os, pickle
import matplotlib.pyplot as plt
import numpy as np

# %%
audio_file_list = pickle.load(open('audio_path_list.pkl', 'rb'))
audio_file_list
# Out:
# ['/import/c4dm-datasets/VocalSet1-2/data_by_singer/female1/arpeggios/belt/f1_arpeggios_belt_c_a.wav',
#  '/import/c4dm-datasets/VocalSet1-2/data_by_singer/female1/arpeggios/belt/f1_arpeggios_belt_c_e.wav',
#  '/import/c4dm-datasets/VocalSet1-2/data_by_singer/female1/arpeggios/belt/f1_arpeggios_belt_c_i.wav',
#  '/import/c4dm-datasets/VocalSet1-2/data_by_singer/female1/arpeggios/belt/f1_arpeggios_belt_c_o.wav',
#  '/import/c4dm-datasets/VocalSet1-2/data_by_singer/female1/arpeggios/belt/f1_arpeggios_belt_c_u.wav',
#  '/import/c4dm-datasets/VocalSet1-2/data_by_singer/female1/arpeggios/breathy/f1_arpeggios_breathy_a.wav',
#  '/import/c4dm-datasets/VocalSet1-2/data_by_singer/female1/arpeggios/breathy/f1_arpeggios_breathy_e.wav',
#  '/import/c4dm-datasets/VocalSet1-2/data_by_singer/female1/arpeggios/breathy/f1_arpeggios_breathy_i.wav',
#  '/import/c4dm-datasets/VocalSet1-2/data_by_singer/female1/arpeggios/breathy/f1_arpeggios_breathy_o.wav',
# ...
